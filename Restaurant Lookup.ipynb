# %%
import requests
import json
import pandas as pd
import time
import urllib.parse

apiKey = "AIzaSyAynZe67hoOdtcUy7FaPMGMJ5yUuUYNRI8"

# %%
add = pd.read_excel("studentHousing.xlsx")
url = []

# %%
def convertAddress(address, cityState):
    index = address.find(",")
    temp = address[0:index]
    combined = temp + " " + cityState

    
    #combined  = combined.replace(" ", "%20")
    combined = combined.replace(",", "")
    return combined

# %%
def getData(address): #get data for a single formatted address
    #getting lat-lon coordinated
    params = {"key": apiKey,"address":address }
    encoded = urllib.parse.urlencode(params,quote_via=urllib.parse.quote)
    r = requests.get("https://maps.googleapis.com/maps/api/geocode/json", params = encoded)
    r.json()
    results = r.json()["results"][0]
    geo = results['geometry']
    location = geo["location"]
    mergedLocation = str(location['lat']) + "," + str(location['lng'])
    toReturn = []
  
    
    
    #getting nearby restaurant names
    
    params = {"key": "AIzaSyAynZe67hoOdtcUy7FaPMGMJ5yUuUYNRI8", "location": mergedLocation, "radius": "400", "type":"restaurant"}
    r = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json",params)
    json = r.json()
    toReturn.append(json["results"])
    url.append(r.url)




   #if there are >20 restaurants
  
    while "next_page_token" in json:
        pagetoken = str(json["next_page_token"])
        time.sleep(1) #give places api time to make next page valid
        params = {"key": "AIzaSyAynZe67hoOdtcUy7FaPMGMJ5yUuUYNRI8", "location": mergedLocation, "radius": "400", "type":"restaurant", "pagetoken": pagetoken}
        
        r = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json",params)
        json = r.json()
        toReturn.append(json["results"])
   
    return toReturn

# %%
def getPlaceInfo(placeId):
    website = "..."
    phone = "..."
    
    try:
        params = {"key": "AIzaSyAynZe67hoOdtcUy7FaPMGMJ5yUuUYNRI8", "place_id": placeId}
        r = requests.get("https://maps.googleapis.com/maps/api/place/details/json",params)
        result = r.json()["result"]
        website = result["website"]
        
    except:
        pass
    
    try:
        phone = result["international_phone_number"]
        
    except:
        pass
    
    return [website, phone]

# %%
def compute(address, cityState, name):
    temp = convertAddress(address, cityState)
    data = getData(temp)
    nearbyNames = []
    for page in data:
        for place in page:
            [website,phone] = getPlaceInfo(place["place_id"])
            
            nearbyNames.append({"name": place["name"],"website": website, "phone": phone , })
    return {"name": name, "address": address, "nearby": nearbyNames}

# %%
final = {}
errors=[]


for index, row in add.iterrows():
    if (index<500):
        name = row["Apartment Name"]
        address = row["Apartment Building"]
        cityState = row["Location"]
        try:
            temp= compute(address, cityState, name)
            final[str(index+2)] = temp
        except:
            temp = convertAddress(address, cityState)
            errors.append([index+2, temp] )
            pass

# %%
errors
# Out:
# []

# %%
#website, phone number, name, cuisine type

# %%
final
# Out:
# {'2': {'name': '108 Place Apartments',
#   'address': '108 W 45th St, Hyde Park',
#   'nearby': []},
#  '3': {'name': 'Crescent',
#   'address': '127 E Riverside Dr, SoCo',
#   'nearby': [{'name': 'Freebirds World Burrito',
#     'website': 'https://freebirds.com/',
#     'phone': '+1 512-462-3512'},
#    {'name': 'ThunderCloud Subs',
#     'website': 'http://www.thundercloud.com/',
#     'phone': '+1 512-441-5331'},
#    {'name': 'Taco Joint',
#     'website': 'http://www.austintacojoint.com/',
#     'phone': '+1 512-599-5144'},
#    {'name': "Don Gume's Tacos", 'website': '...', 'phone': '+1 512-804-6614'},
#    {'name': "Oui's Thai Cuisine",
#     'website': '...',
#     'phone': '+1 512-720-8335'},
#    {'name': 'sweetgreen',
#     'website': 'http://order.sweetgreen.com/?utm_source=google_listing&utm_medium=yext&utm_campaign=visit_main_website_CTA',
#     'phone': '+1 737-255-8900'},
#    {'name': 'Prim and Proper',
#     'website': 'https://neighborhoodgoods.com/',
#     'phone': '+1 512-531-9066'},
#    {'name': 'Aba',
#     'website': 'https://www.abarestaurants.com/austin/',
#     'phone': '...'}]},
#  '4': {'name': 'Urbana at Goodnight Ranch',
#   'address': '9005 Alderman Dr, Southeast Austin',
#   'nearby': []},
#  '5': {'name': 'Bridge at Cameron',
#   'address': '9201 Cameron Rd, Walnut Creek',
#   'nearby': [{'name': "Domino's Pizza",
#     'website': 'https://www.dominos.com/en/?redirect=homepage&utm_source=google&utm_medium=loclist&utm_campaign=localmaps',
#     'phone': '+1 512-614-0031'},
#    {'name': "Ken's Tacos",
#     'website': 'http://www.kenstacos.com/index.html',
#     'phone': '+1 512-837-9370'},
#    {'name': "BUDDY'S", 'website': '...', 'phone': '+1 512-852-8493'},
#    {'name': "Buddy's Mexican Grill",
#     'website': '...',
#     'phone': '+1 512-873-0667'},
#    {'name': "Buddy's Burger",
#     'website': 'http://www.buddysburger.com/',
#     'phone': '+1 512-401-3325'},
#    {'name': 'Taco Hot', 'website': '...', 'phone': '+1 512-986-9209'},
#    {'name': 'Los Reyes Del Taco', 'website': '...', 'phone': '...'}]},
#  '6': {'name': 'Radius On Grove',
#   'address': '2301 Grove Blvd, Montopolis',
#   'nearby': [{'name': 'Crazy Fruits Riverside',
#     'website': 'http://www.crazyfruitsaustin.com/',
#     'phone': '+1 512-906-2986'},
#    {'name': 'Tacos La Sabroza',
#     'website': '...',
#     'phone': '+1 512-791-5150'}]},
#  '7': {'name': 'FLORA',
#   'address': '5406 Middle Fiskville Rd, North Loop',
#   'nearby': [{'name': 'East Side Pies',
#     'website': 'http://www.eastsidepies.com/?utm_source=Google%20My%20Business&utm_medium=Website&utm_campaign=Austin',
#     'phone': '+1 512-454-7437'},
#    {'name': 'Daruma Ramen',
#     'website': 'http://www.darumaramen.com/',
#     'phone': '+1 512-712-5700'},
#    {'name': 'Komé',
#     'website': 'http://www.kome-austin.com/',
#     'phone': '+1 512-712-5700'},
#    {'name': 'Quality Seafood Market',
#     'website': 'http://qualityseafoodmarket.com/',
#     'phone': '+1 512-452-3820'},
#    {'name': 'Bistro Vonish',
#     'website': 'https://www.bistrovonish.com/',
#     'phone': '+1 512-579-9854'},
#    {'name': 'Zucchini Kill',
#     'website': 'http://zucchinikill.com/',
#     'phone': '+1 737-215-5936'},
#    {'name': 'Sala and Betty',
#     'website': 'http://www.salaandbettyatx.com/',
#     'phone': '+1 512-645-0214'},
#    {'name': 'Wasota Vegan Paradise',
#     'website': '...',
#     'phone': '+1 512-565-3864'},
#    {'name': 'Sundaze',
#     'website': 'http://sundazetx.com/',
#     'phone': '+1 737-230-3095'},
#    {'name': 'Oyster Bar And Restaurant', 'website': '...', 'phone': '...'},
#    {'name': 'Home Slice Pizza',
#     'website': 'http://homeslicepizza.com/',
#     'phone': '+1 512-707-7437'}]},
#  '8': {'name': 'The Elizabeth at Presidio',
#   'address': '13500 Lyndhurst St, Avery Ranch',
#   'nearby': []},
#  '9': {'name': 'Flatiron Domain',
#   'address': '10727 Domain Dr, Domain',
#   'nearby': [{'name': "Maggiano's Little Italy",
#     'website': 'https://locations.maggianos.com/texas/austin/10910-domain-dr./?utm_source=google&utm_medium=organic&utm_campaign=localmaps',
#     'phone': '+1 512-501-7870'},
#    {'name': 'Sushi Zushi',
#     'website': 'https://www.sushizushi.com/',
#     'phone': '+1 512-834-8100'},
#    {'name': 'Subway',
#     'website': 'https://order.subway.com/en-us/restaurant/49510/menu/?utm_source=yxt-goog&utm_medium=local&utm_term=acq&utm_content=49510&utm_campaign=evergreen-2020',
#     'phone': '+1 512-640-5444'},
#    {'name': 'Beirut Restaurant',
#     'website': 'http://www.facebook.com/Beirutaustin/',
#     'phone': '+1 512-758-3377'},
#    {'name': 'CAVA',
#     'website': 'https://cava.com/locations/the-domain-tx',
#     'phone': '+1 512-967-1709'},
#    {'name': 'The Water Trough',
#     'website': 'https://www.lonestarcourt.com/water-trough.htm',
#     'phone': '+1 512-814-2625'},
#    {'name': 'Paradise Smoothies',
#     'website': '...',
#     'phone': '+1 512-330-4498'},
#    {'name': 'Flaming Pizza',
#     'website': 'http://flamingpizzausa.com/',
#     'phone': '+1 512-792-9595'},
#    {'name': 'Greens ‘n Grill',
#     'website': 'http://greensngrill.com/',
#     'phone': '+1 512-740-1853'},
#    {'name': 'Aurora Venezuelan Food',
#     'website': 'https://www.facebook.com/AuroraVenezuelanFood/',
#     'phone': '+1 737-228-6210'}]},
#  '10': {'name': 'Century Travesia',
#   'address': '4301 Grand Avenue Pky, Wells Branch',
#   'nearby': []},
#  '11': {'name': 'Platform',
#   'address': '2823 E Martin Luther King Jr Blvd, Chestnut',
#   'nearby': []},
#  '12': {'name': 'The Santal',
#   'address': '7624 Tecoma Cir, East Oak Hill',
#   'nearby': []},
#  '13': {'name': 'Chandelier',
#   'address': '2336 Douglas St, Parker Lane',
#   'nearby': [{'name': '888 Pan Asian Restaurant',
#     'website': 'https://888panasian.business.site/',
#     'phone': '+1 512-448-4722'},
#    {'name': "Domino's Pizza",
#     'website': 'https://www.dominos.com/en/?utm_source=google&utm_medium=loclist&utm_campaign=localmaps',
#     'phone': '+1 512-447-6681'},
#    {'name': 'Hai Ky',
#     'website': 'http://austinhaiky.com/',
#     'phone': '+1 512-693-2464'},
#    {'name': "Papa John's Pizza",
#     'website': 'https://locations.papajohns.com/united-states/tx/78741/austin/2200-e-oltorf-st?utm_source=gmb&utm_medium=organic&y_source=1_MTA2OTE5NzQtNzE1LWxvY2F0aW9uLmdvb2dsZV93ZWJzaXRlX292ZXJyaWRl',
#     'phone': '+1 512-416-7272'},
#    {'name': 'El Pollo Rico # 6',
#     'website': 'http://pollosricos.com/',
#     'phone': '+1 512-444-7426'},
#    {'name': 'Jack in the Box',
#     'website': 'https://locations.jackinthebox.com/us/tx/austin/1936-e-oltorf-st',
#     'phone': '+1 512-462-2676'},
#    {'name': 'Circle K',
#     'website': 'https://www.circlek.com/store-locator/us/austin/2222-e-oltorf-st/2740552',
#     'phone': '+1 512-444-8429'},
#    {'name': 'El Jacalito',
#     'website': 'https://el-jacalito-mexican-restaurant.business.site/',
#     'phone': '+1 512-445-4109'},
#    {'name': 'Het Say Vietnamese Kitchen',
#     'website': 'https://www.hetsayaustin.com/',
#     'phone': '+1 512-443-4232'},
#    {'name': 'Taqueria Chapala #5',
#     'website': '...',
#     'phone': '+1 512-792-9416'},
#    {'name': 'La michocana', 'website': '...', 'phone': '...'},
#    {'name': 'El SUPER TACO',
#     'website': 'https://m.facebook.com/profile.php?id=215200215207611&ref=content_filter',
#     'phone': '+1 512-203-4932'},
#    {'name': 'Tacos', 'website': '...', 'phone': '...'},
#    {'name': 'Taqueria La Chopa', 'website': '...', 'phone': '+1 512-369-9014'},
#    {'name': 'La tunita 512', 'website': '...', 'phone': '...'},
#    {'name': '888 Vietnamese Restaurant',
#     'website': 'https://888panasian.business.site/',
#     'phone': '+1 512-448-4722'},
#    {'name': 'Comida Asian', 'website': '...', 'phone': '...'}]},
#  '14': {'name': 'The Davis Soco Apartments',
#   'address': '3801 S Congress Ave, South Central Austin',
#   'nearby': [{'name': "P. Terry's Burger Stand",
#     'website': 'http://pterrys.com/',
#     'phone': '+1 512-462-4998'},
#    {'name': "McDonald's",
#     'website': 'https://www.mcdonalds.com/us/en-us/location/TX/AUSTIN/3909-S-CONGRESS-AVE/23614.html?cid=RF:YXT:GMB::Clicks',
#     'phone': '+1 512-448-9485'},
#    {'name': 'El Borrego De Oro', 'website': '...', 'phone': '+1 512-383-0031'},
#    {'name': 'ThunderCloud Subs',
#     'website': 'http://www.thundercloud.com/',
#     'phone': '+1 512-447-7827'},
#    {'name': 'Sisters & Brothers Inc',
#     'website': 'http://sassproducts.com/',
#     'phone': '+1 512-326-3304'},
#    {'name': 'Taste of Ethiopia II',
#     'website': 'http://www.tasteofethiopiaaustin.com/',
#     'phone': '+1 512-814-3141'},
#    {'name': 'Hoeks Death Metal Pizza Austin',
#     'website': '...',
#     'phone': '+1 512-621-6938'},
#    {'name': 'Pueblo Viejo Taco Truck',
#     'website': 'http://www.puebloviejoaustin.com/',
#     'phone': '+1 512-762-2566'},
#    {'name': 'Leroy And Lewis Barbecue',
#     'website': 'http://leroyandlewis.com/',
#     'phone': '+1 512-945-9882'},
#    {'name': 'Papalote Taco House',
#     'website': 'http://yumpapalote.com/',
#     'phone': '+1 512-294-2122'},
#    {'name': 'Texas Ranch BBQ',
#     'website': 'http://www.twelvebones.com/',
#     'phone': '+1 512-294-2122'},
#    {'name': 'El Paisa', 'website': '...', 'phone': '...'},
#    {'name': 'TOMMY WANT WINGY',
#     'website': 'http://www.tommywantwingyatx.com/#contact',
#     'phone': '+1 512-662-8516'},
#    {'name': 'Taqueria La Esperanza',
#     'website': '...',
#     'phone': '+1 512-680-2943'},
#    {'name': 'Plaza Colombian Coffee',
#     'website': 'http://www.plazacolombiancoffee.com/',
#     'phone': '+1 512-825-0738'},
#    {'name': 'Pupuseria Y Taqueria Don Benny',
#     'website': '...',
#     'phone': '+1 512-656-4457'},
#    {'name': 'Pupuseria Y Taqueria Don Benny’s',
#     'website': '...',
#     'phone': '...'}]},
#  '15': {'name': 'Bristol Heights',
#   'address': '12041 Dessau Rd, Parmer Lane',
#   'nearby': []},
#  '16': {'name': 'Riata',
#   'address': '12300 Riata Trace Pky, Angus Ranch',
#   'nearby': [{'name': 'Riata Bar and Grill',
#     'website': 'http://www.riatabarandgrill.com/',
#     'phone': '+1 512-336-3838'},
#    {'name': "Minh's Cafe",
#     'website': 'https://minhscafe.menufy.com/',
#     'phone': '+1 512-249-6464'},
#    {'name': 'Nanking', 'website': '...', 'phone': '...'}]},
#  '17': {'name': 'The District on La Frontera',
#   'address': '2811 La Frontera Blvd, Wells Branch',
#   'nearby': [{'name': 'BO ASIAN BISTRO - CHINESE RESTAURANT',
#     'website': 'http://www.boasianbistro.com/',
#     'phone': '+1 512-388-7033'},
#    {'name': 'Veracruz All Natural',
#     'website': 'https://www.veracruzallnatural.com/',
#     'phone': '+1 512-388-6595'},
#    {'name': 'Original Brooklyn Pie Co.',
#     'website': 'http://www.brooklynpie.com/',
#     'phone': '+1 512-255-1505'},
#    {'name': 'Pho Dan', 'website': '...', 'phone': '+1 512-527-3699'}]},
#  '18': {'name': 'Ethos Apartments',
#   'address': '8001 S IH35, McKinney',
#   'nearby': []},
#  '19': {'name': 'Corazon Apartments',
#   'address': '1000 E 5th St, Plaza Saltillo',
#   'nearby': [{'name': 'Spartan Pizza',
#     'website': 'http://spartanpizzaaustin.com/',
#     'phone': '+1 512-484-0798'},
#    {'name': 'Buenos Aires Café',
#     'website': 'http://www.buenosairescafe.com/',
#     'phone': '+1 512-382-1189'},
#    {'name': "Wendy's",
#     'website': 'https://locations.wendys.com/united-states/tx/austin/619-n-ih-35?utm_source=Yext&utm_medium=Google_My_Business&utm_campaign=Local_Search&utm_content=EN_US',
#     'phone': '+1 512-596-3249'},
#    {'name': 'The North Door',
#     'website': 'http://ndvenue.com/',
#     'phone': '+1 512-710-9765'},
#    {'name': 'Fukumoto Sushi & Yakitori Izakaya',
#     'website': 'http://fukumotoaustin.com/',
#     'phone': '+1 512-770-6880'},
#    {'name': 'Artessano',
#     'website': 'http://www.facebook.com/atxartessano/',
#     'phone': '+1 512-387-5353'},
#    {'name': 'Sweet Heat Meat', 'website': '...', 'phone': '...'},
#    {'name': 'El Milagro Tortilla',
#     'website': '...',
#     'phone': '+1 512-392-3258'},
#    {'name': "Angie's",
#     'website': 'https://www.angiesmx.com/',
#     'phone': '+1 512-476-5413'},
#    {'name': 'Pueblo Viejo',
#     'website': 'http://www.puebloviejoaustin.com/',
#     'phone': '+1 512-373-6557'},
#    {'name': 'Snooze, an A.M. Eatery E. Austin',
#     'website': 'https://www.snoozeeatery.com/',
#     'phone': '+1 512-886-1550'},
#    {'name': 'Hopdoddy Burger Bar',
#     'website': 'http://www.hopdoddy.com/locations/',
#     'phone': '...'},
#    {'name': 'JuiceLand',
#     'website': 'http://www.juiceland.com/',
#     'phone': '+1 512-579-0521'},
#    {'name': 'Chipotle Mexican Grill',
#     'website': 'https://locations.chipotle.com/tx/austin/1109-e-5th-st?utm_source=google&utm_medium=yext&utm_campaign=yext_listings',
#     'phone': '+1 512-582-1444'},
#    {'name': 'East Austin Hotel',
#     'website': 'http://eastaustinhotel.com/',
#     'phone': '+1 737-205-8888'},
#    {'name': 'Cool Beans',
#     'website': 'http://www.coolbeanseatery.com/',
#     'phone': '+1 512-887-8139'},
#    {'name': 'Pool Bar at East Austin Hotel',
#     'website': 'https://eastaustinhotel.com/food-drink/pool-bar/',
#     'phone': '+1 737-205-8917'},
#    {'name': 'Sixth and Waller',
#     'website': 'https://eastaustinhotel.com/food-drink/6th-and-waller/',
#     'phone': '+1 737-205-8916'},
#    {'name': 'Gyu-Kaku Japanese BBQ',
#     'website': 'https://www.gyu-kaku.com/austin/',
#     'phone': '+1 737-209-0351'},
#    {'name': 'Pepitos 512',
#     'website': 'https://pepitos512.com/',
#     'phone': '+1 512-574-2953'}]},
#  '20': {'name': 'The Flats on San Felipe',
#   'address': "7920 San Felipe Blvd, Hunter's Chase",
#   'nearby': [{'name': 'Corner Store',
#     'website': 'https://www.circlek.com/store-locator/us/austin/13014-pond-springs-rd/2742110',
#     'phone': '+1 512-335-7277'}]},
#  '21': {'name': '3401 at Red River',
#   'address': '3401 Red River, Hancock',
#   'nearby': [{'name': "Jimmy John's",
#     'website': 'https://locations.jimmyjohns.com/tx/austin/sandwiches-416.html?utm_source=google%20my%20business&utm_medium=organic&utm_campaign=website%20link',
#     'phone': '+1 512-499-0100'},
#    {'name': 'Cafe at Barclay Park', 'website': '...', 'phone': '...'}]},
#  '22': {'name': 'Residences at The Triangle',
#   'address': '4600 W Guadalupe St, The Triangle',
#   'nearby': [{'name': "Mandola's Italian",
#     'website': 'https://mandolas.com/',
#     'phone': '+1 512-419-9700'},
#    {'name': 'MezzeMe',
#     'website': 'http://www.mezzeme.com/',
#     'phone': '+1 512-900-8200'},
#    {'name': 'Hopdoddy Burger Bar',
#     'website': 'https://www.hopdoddy.com/menu/?id-26637',
#     'phone': '+1 512-335-2337'},
#    {'name': "Mama Fu's Asian House",
#     'website': 'https://locations.mamafus.com/tx/austin/4700-w--guadalupe-st-.html?y_source=1_OTgwNjk5MS03MTUtbG9jYXRpb24uZ29vZ2xlX3dlYnNpdGVfb3ZlcnJpZGU%3D',
#     'phone': '+1 512-637-6773'},
#    {'name': "Jersey Mike's Subs",
#     'website': 'https://www.jerseymikes.com/15085',
#     'phone': '+1 512-467-7827'},
#    {'name': 'Pho MPH', 'website': 'https://phomphaustin.com/', 'phone': '...'},
#    {'name': 'Pho MPH',
#     'website': 'http://www.phomphaustin.com/',
#     'phone': '+1 512-852-8008'}]},
#  '23': {'name': 'Cliffs at Barton Creek',
#   'address': '3050 Tamarron Blvd, Barton Creek',
#   'nearby': []},
#  '24': {'name': 'The Muse at SoCo',
#   'address': '1007 S Congress Ave, SoCo',
#   'nearby': [{'name': 'Freebirds World Burrito',
#     'website': 'https://freebirds.com/',
#     'phone': '+1 512-462-3512'},
#    {'name': "Jo's Coffee",
#     'website': 'http://www.joscoffee.com/',
#     'phone': '+1 512-444-3800'},
#    {'name': "Joann's Fine Foods",
#     'website': 'http://www.joannsaustin.com/',
#     'phone': '+1 512-358-6054'},
#    {'name': 'ThunderCloud Subs',
#     'website': 'http://www.thundercloud.com/',
#     'phone': '+1 512-441-5331'},
#    {'name': 'Lucky Robot',
#     'website': 'http://www.luckyrobotrestaurant.com/',
#     'phone': '+1 512-444-8081'},
#    {'name': 'sweetgreen',
#     'website': 'http://order.sweetgreen.com/?utm_source=google_listing&utm_medium=yext&utm_campaign=visit_main_website_CTA',
#     'phone': '+1 737-255-8900'},
#    {'name': 'Prim and Proper',
#     'website': 'https://neighborhoodgoods.com/',
#     'phone': '+1 512-531-9066'},
#    {'name': 'Taco Joint',
#     'website': 'http://www.austintacojoint.com/',
#     'phone': '+1 512-599-5144'},
#    {'name': "Don Gume's Tacos", 'website': '...', 'phone': '+1 512-804-6614'},
#    {'name': "Oui's Thai Cuisine",
#     'website': '...',
#     'phone': '+1 512-720-8335'},
#    {'name': 'Aba',
#     'website': 'https://www.abarestaurants.com/austin/',
#     'phone': '...'}]},
#  '25': {'name': 'East Vue Ranch Apartment',
#   'address': '460 Bastrop Hwy, Riverside',
#   'nearby': [{'name': "Mama'S Tacos",
#     'website': '...',
#     'phone': '+1 512-627-0748'},
#    {'name': 'Elotes mexicanos 100%',
#     'website': '...',
#     'phone': '+1 512-743-9016'},
#    {'name': 'Taqueria la sabrosita',
#     'website': '...',
#     'phone': '+1 512-576-1997'}]},
#  '26': {'name': 'The Saint Mary',
#   'address': '7500 W Slaughter Ln, Circle C Ranch',
#   'nearby': []},
#  '27': {'name': 'St Johns West',
#   'address': '601 W Saint Johns Ave, Highland',
#   'nearby': [{'name': 'Black Star Co-op',
#     'website': 'http://www.blackstar.coop/',
#     'phone': '+1 512-452-2337'},
#    {'name': "Chago's",
#     'website': 'http://www.chagosatx.com/',
#     'phone': '+1 512-275-6013'},
#    {'name': 'Kura Revolving Sushi Bar - Now Open',
#     'website': 'https://kurasushi.com/locations/austin-tx-airport-blvd/',
#     'phone': '+1 737-209-8799'},
#    {'name': 'Midtown Grocery & Cafe',
#     'website': 'http://facebook.com/midtowngrocery',
#     'phone': '+1 512-382-9450'},
#    {'name': 'Fat Cats Organic Coffee & Desserts',
#     'website': 'http://www.fatcatsaustin.com/',
#     'phone': '+1 512-296-2960'},
#    {'name': 'Rice Ball CO.',
#     'website': 'https://rice-ball-co.business.site/?utm_source=gmb&utm_medium=referral',
#     'phone': '+1 512-433-6872'},
#    {'name': 'Sazan Ramen',
#     'website': 'http://sazanramen.com/',
#     'phone': '+1 512-432-5474'},
#    {'name': 'BBQ Chicken Highland Village',
#     'website': 'https://bbdotqchicken.com/menu/',
#     'phone': '+1 512-344-9014'},
#    {'name': 'Fresko Eats',
#     'website': 'https://freskoeats.com/',
#     'phone': '+1 512-419-0006'},
#    {'name': 'Fruitealicious',
#     'website': 'http://www.fruitealicious.com/',
#     'phone': '+1 512-284-9377'},
#    {'name': 'Kura Sushi',
#     'website': 'https://kurasushi.com/locations/austin-tx-airport-blvd/',
#     'phone': '...'},
#    {'name': '101 by Tea Haus',
#     'website': 'http://teahaus101.com/',
#     'phone': '+1 512-371-7751'},
#    {'name': 'Taqueria Los Jaliscienses',
#     'website': '...',
#     'phone': '+1 512-419-7340'},
#    {'name': '85°C Bakery Cafe',
#     'website': 'http://85cbakerycafe.com/',
#     'phone': '+1 512-436-8189'},
#    {'name': "Mijo's at Crestview Station",
#     'website': 'http://mijos.co/',
#     'phone': '...'},
#    {'name': 'Shishman Halal Mediterranean',
#     'website': 'http://www.shishmangrill.com/',
#     'phone': '+1 512-243-5289'}]},
#  '28': {'name': 'The Palisades',
#   'address': '307 E 31st St',
#   'nearby': [{'name': "Sao Paulo's Restaurant",
#     'website': 'http://www.saopaulos.net/',
#     'phone': '+1 512-473-9988'},
#    {'name': 'Posse East',
#     'website': 'http://www.posseeast.com/',
#     'phone': '+1 512-477-2111'},
#    {'name': 'Taco Joint',
#     'website': 'http://www.austintacojoint.com/',
#     'phone': '+1 512-473-8223'},
#    {'name': 'Vaquero Taquero',
#     'website': 'http://vaquerotaquero.com/',
#     'phone': '+1 512-366-5578'}]},
#  '29': {'name': 'Trone Villa',
#   'address': '8905 Tronewood Dr',
#   'nearby': [{'name': 'Tan My Restaurant',
#     'website': '...',
#     'phone': '+1 512-832-9585'}]},
#  '30': {'name': 'Marsol Apartments',
#   'address': '1610 Enfield Rd',
#   'nearby': [{'name': 'Cipollina',
#     'website': 'http://www.cipollina-austin.com/',
#     'phone': '+1 512-477-5211'},
#    {'name': "Jeffrey's",
#     'website': 'http://jeffreysofaustin.com/',
#     'phone': '+1 512-477-5584'},
#    {'name': "Nau's Enfield Drug",
#     'website': 'http://www.nausdrug.com/',
#     'phone': '+1 512-476-1221'},
#    {'name': 'Josephine House',
#     'website': 'http://josephineofaustin.com/',
#     'phone': '+1 512-477-5584'},
#    {'name': 'Taco Flats Clarksville',
#     'website': 'http://tacoflats.com/',
#     'phone': '+1 512-472-8226'}]},
#  '31': {'name': 'Cherry Hill Lofts',
#   'address': '5609 Cougar Dr, Garrison Park',
#   'nearby': [{'name': 'Milano Pizza',
#     'website': 'http://milanopizzaaustin.com/',
#     'phone': '+1 512-440-0866'},
#    {'name': '1st Wok',
#     'website': 'http://www.1stwoktx.com/',
#     'phone': '+1 512-444-0077'},
#    {'name': 'Las Lomas Tex-Mex Cantina',
#     'website': 'http://www.laslomastexmex.com/',
#     'phone': '+1 512-428-9425'},
#    {'name': "Cilantro's Mexican Restaurant",
#     'website': '...',
#     'phone': '+1 512-707-1207'},
#    {'name': 'El Pollo Rico # 4',
#     'website': 'http://pollosricos.com/',
#     'phone': '+1 512-445-7474'},
#    {'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/austin/804-w.-stassney-lane.html',
#     'phone': '+1 512-444-9519'},
#    {'name': 'Golden Fried - Sophia', 'website': '...', 'phone': '...'},
#    {'name': 'Golden Chick',
#     'website': 'http://locations.goldenchick.com/tx/austin/1043/?utm_source=Google&utm_medium=Maps&utm_campaign=Google+Places',
#     'phone': '+1 512-445-4242'}]},
#  '32': {'name': 'Allandale Flats',
#   'address': '2412 Richcreek Rd, Allandale',
#   'nearby': [{'name': 'Top Notch Hamburgers',
#     'website': 'http://www.topnotchaustin.com/',
#     'phone': '+1 512-452-2181'},
#    {'name': 'El Mercado Restaurant',
#     'website': 'https://www.elmercadorestaurant.com/',
#     'phone': '+1 512-454-2500'},
#    {'name': 'Ichiban',
#     'website': 'http://www.austinichiban.com/',
#     'phone': '+1 512-458-3700'},
#    {'name': 'JuiceLand',
#     'website': 'http://www.juiceland.com/',
#     'phone': '+1 512-524-1129'},
#    {'name': 'Pizza Galore',
#     'website': 'https://pizzagaloretx.com/',
#     'phone': '+1 512-451-8999'},
#    {'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/austin/7708-n.-burnet-road.html',
#     'phone': '+1 512-451-9266'},
#    {'name': 'Pizza Land and Asian Cuisine',
#     'website': 'http://www.pizzalandasiancuisine.com/',
#     'phone': '+1 512-451-8666'},
#    {'name': 'Tacodeli',
#     'website': 'http://www.tacodeli.com/',
#     'phone': '+1 512-467-9999'},
#    {'name': 'dipdipdip Tatsu-Ya',
#     'website': 'https://www.dipdipdip-tatsuya.com/',
#     'phone': '+1 512-298-6289'},
#    {'name': 'Tumble22',
#     'website': 'http://tumble22.com/',
#     'phone': '+1 512-520-1998'},
#    {'name': 'The Local Post Pub',
#     'website': 'http://www.thelocalpost.pub/',
#     'phone': '+1 512-375-5599'},
#    {'name': 'Alejandra work', 'website': '...', 'phone': '...'}]},
#  '33': {'name': 'St. Thomas Condominiums',
#   'address': '807 W 25th St, West Campus Austin',
#   'nearby': [{'name': 'Pluckers Wing Bar',
#     'website': 'http://www.pluckers.com/',
#     'phone': '+1 512-469-9464'},
#    {'name': 'Starbucks',
#     'website': 'http://www.starbucks.com/store/16692/',
#     'phone': '+1 512-472-5211'},
#    {'name': "Cain & Abel's",
#     'website': 'http://abels.com/original',
#     'phone': '+1 512-476-3201'},
#    {'name': "Madam Mam's Thai Cuisine, UT West Campus at 26th ST",
#     'website': 'http://www.madammam.com/',
#     'phone': '+1 512-305-3955'},
#    {'name': 'Sushi Niichi', 'website': '...', 'phone': '+1 512-469-0499'},
#    {'name': 'Holy Macaroni', 'website': '...', 'phone': '+1 972-322-4095'},
#    {'name': "Aj's Pizzaria On Wheels",
#     'website': '...',
#     'phone': '+1 512-358-1114'},
#    {'name': 'Raku Sushi & Asian Bistro',
#     'website': 'https://rakusushiaustin.com/',
#     'phone': '+1 512-297-2778'},
#    {'name': 'Smoothie King',
#     'website': 'https://locations.smoothieking.com/ll/US/TX/Austin/504-W_-24th-Street*-Suite-B',
#     'phone': '+1 512-480-5095'},
#    {'name': 'korean komfort',
#     'website': 'http://www.korean-komfort.com/',
#     'phone': '+1 512-920-0969'},
#    {'name': 'Darlene ann Vasquez', 'website': '...', 'phone': '...'},
#    {'name': 'Mango 8', 'website': '...', 'phone': '+1 512-519-9477'},
#    {'name': 'Chef Hong', 'website': '...', 'phone': '+1 678-687-1167'},
#    {'name': 'Momora Austin Food',
#     'website': 'https://momoraaustinfood.com/',
#     'phone': '+1 512-595-9470'},
#    {'name': 'King’s BBQ & Soul', 'website': '...', 'phone': '+1 512-354-0101'},
#    {'name': 'Longhorn Chicken',
#     'website': 'https://longhornchicken.fun/',
#     'phone': '+1 512-720-2334'},
#    {'name': 'Morales', 'website': '...', 'phone': '+1 512-203-0910'},
#    {'name': 'Suns Out Buns Out Burger Company Austin TX',
#     'website': 'https://suns-out-buns-out-burger-company-austin-tx.business.site/?utm_source=gmb&utm_medium=referral',
#     'phone': '...'},
#    {'name': 'Cold Cookie Company',
#     'website': 'http://coldcookiecompany.com/',
#     'phone': '+1 512-305-3771'},
#    {'name': "JP'S Pancake Company",
#     'website': 'http://jpspancakecompany.com/',
#     'phone': '+1 512-200-3099'},
#    {'name': 'Pastelaria São Paulo',
#     'website': 'https://m.facebook.com/pspaustin/',
#     'phone': '+1 512-998-9688'},
#    {'name': "Bao'd Up Chinese Comfort Food - UT West Campus",
#     'website': 'http://www.baodup.com/',
#     'phone': '+1 512-505-8080'},
#    {'name': 'Espadas de Brazil',
#     'website': 'http://espadasdebrazil.com/',
#     'phone': '+1 512-965-3181'},
#    {'name': 'Hotplate',
#     'website': 'http://www.hotplate.com/',
#     'phone': '+1 214-912-1303'},
#    {'name': 'Reqw', 'website': '...', 'phone': '...'},
#    {'name': 'UTea Pho',
#     'website': 'https://utea-pho.business.site/',
#     'phone': '+1 512-394-7657'},
#    {'name': 'ALPETRA mediterranean food',
#     'website': '...',
#     'phone': '+1 512-970-4042'}]},
#  '34': {'name': 'Cliff House Apartments',
#   'address': '513 Pecan Grove Rd, SoCo',
#   'nearby': [{'name': "Justin's Cantina",
#     'website': '...',
#     'phone': '+1 915-538-7282'}]},
#  '35': {'name': 'Galewood Village Apartments',
#   'address': '8930 Galewood Dr, North Austin',
#   'nearby': [{'name': 'Tan My Restaurant',
#     'website': '...',
#     'phone': '+1 512-832-9585'},
#    {'name': 'El Pollo Rico',
#     'website': 'http://pollosricos.com/',
#     'phone': '+1 512-551-9845'},
#    {'name': 'Mi Casa', 'website': '...', 'phone': '+1 512-374-0770'},
#    {'name': 'Tuzantla Taqueria', 'website': '...', 'phone': '+1 512-350-5823'},
#    {'name': 'Hacienda Jalisco restaurant',
#     'website': 'https://hacienda-jalisco-restaurant.negocio.site/',
#     'phone': '+1 512-374-0770'},
#    {'name': 'Fruteria Pekitas',
#     'website': 'https://www.facebook.com/pages/category/Fast-Food-Restaurant/Fruteria-Pekitas-208519652830572/',
#     'phone': '+1 512-520-4865'},
#    {'name': 'El Polio Regio No 6',
#     'website': '...',
#     'phone': '+1 512-491-8449'},
#    {'name': 'Ñoños Tacos #2',
#     'website': 'https://nonostacos.com/',
#     'phone': '+1 512-294-2352'}]},
#  '36': {'name': 'Hyde Park Flats',
#   'address': '4111 Avenue A, Hyde Park',
#   'nearby': [{'name': 'Vino Vino',
#     'website': 'http://www.vinotx.com/',
#     'phone': '+1 512-465-9282'},
#    {'name': 'The Parlor',
#     'website': 'http://theparloraustin.com/',
#     'phone': '+1 512-323-0440'},
#    {'name': 'Mongers',
#     'website': 'http://www.mongersaustin.com/',
#     'phone': '+1 512-215-8972'},
#    {'name': 'Circle K',
#     'website': 'https://www.circlek.com/store-locator/us/austin/3909-guadalupe-st/2740080',
#     'phone': '+1 512-452-5575'},
#    {'name': 'New World Deli',
#     'website': 'http://www.neworldeli.com/',
#     'phone': '+1 512-451-7170'}]},
#  '37': {'name': 'Grigsby Place',
#   'address': '1625 Grigsby Ave, Knox Henderson',
#   'nearby': [{'name': "Mai's Restaurant Authentic Vietnamese Cuisine",
#     'website': 'http://www.maisrestaurant.net/',
#     'phone': '+1 214-826-9887'},
#    {'name': 'Urbano Cafe',
#     'website': 'http://www.urbanodallas.com/',
#     'phone': '+1 214-823-8550'},
#    {'name': 'Popeyes Louisiana Kitchen',
#     'website': 'https://www.popeyes.com/store-locator/store/restaurant_82691',
#     'phone': '+1 214-821-8870'},
#    {'name': 'Pizza Hut',
#     'website': 'https://locations.pizzahut.com/tx/dallas/4540-ross-avenue?utm_medium=organic&utm_source=local&utm_campaign=googlelistings&utm_content=website&utm_term=310546',
#     'phone': '+1 214-827-1177'},
#    {'name': 'Uptown Thai Market',
#     'website': 'http://www.uptownthaidallas.com/',
#     'phone': '+1 469-334-0434'},
#    {'name': 'La Popular Tamale House',
#     'website': 'http://www.lapopulartamalehouse.com/',
#     'phone': '+1 214-824-7617'},
#    {'name': 'Marysols Mexican Restaurant',
#     'website': '...',
#     'phone': '+1 214-823-8879'},
#    {'name': 'Sakhuu Thai Restaurant (Dallas Location)',
#     'website': 'https://order.sakhuuthai.com/order/sakhuu-thai-restaurant-dallas-location',
#     'phone': '+1 214-828-9300'},
#    {'name': 'Dallasite Billiards',
#     'website': '...',
#     'phone': '+1 214-826-3670'},
#    {'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/dallas/4801-ross-avenue.html',
#     'phone': '+1 469-778-2433'},
#    {'name': 'The Hubcap Cafe',
#     'website': 'https://www.dallas24hourclub.org/the-hubcap-cafe',
#     'phone': '+1 214-823-3200'},
#    {'name': 'Top Round',
#     'website': 'https://eattopround.com/',
#     'phone': '+1 214-647-1075'},
#    {'name': 'Khao Noodle Shop',
#     'website': 'http://khaodallas.com/',
#     'phone': '+1 972-803-3373'},
#    {'name': "Giuseppe's Italian Kitchen",
#     'website': 'https://giuseppes-italian-kitchen.business.site/',
#     'phone': '+1 469-766-0181'}]},
#  '38': {'name': 'Caldwell Courts',
#   'address': '2614-2618 Jeffries, South Boulevard-Park Row',
#   'nearby': [{'name': 'Henderson Chicken',
#     'website': 'http://hendersonchicken.com/',
#     'phone': '+1 214-238-2775'},
#    {'name': 'Dollface Beauty Salon',
#     'website': 'http://dollfaceartistrymakeup.com/',
#     'phone': '+1 214-919-5727'},
#    {'name': 'Good Luck Chicken Seafood and Hamburger',
#     'website': '...',
#     'phone': '+1 214-421-5024'},
#    {'name': 'Southside Steaks and Cakes',
#     'website': 'http://southsidesteaksandcakes.com/',
#     'phone': '+1 469-399-7644'},
#    {'name': "T'eddys Deep South Cuisine",
#     'website': '...',
#     'phone': '+1 214-565-5535'},
#    {'name': 'Texas wing stop',
#     'website': 'https://texas-wing-stop.business.site/',
#     'phone': '+1 214-272-3337'}]},
#  '39': {'name': '5010-5014 San Jacinto St',
#   'address': '5010-5014 San Jacinto St, Knox Henderson',
#   'nearby': [{'name': "Mai's Restaurant Authentic Vietnamese Cuisine",
#     'website': 'http://www.maisrestaurant.net/',
#     'phone': '+1 214-826-9887'},
#    {'name': 'Wingstop',
#     'website': 'https://www.wingstop.com/location/wingstop-9-dallas-tx-75206/menu?utm_source=google&utm_medium=distrib&utm_campaign=google-distrib',
#     'phone': '+1 214-821-9464'},
#    {'name': 'Urbano Cafe',
#     'website': 'http://www.urbanodallas.com/',
#     'phone': '+1 214-823-8550'},
#    {'name': 'Waffle House',
#     'website': 'http://www.wafflehouse.com/',
#     'phone': '+1 214-824-2539'},
#    {'name': 'Burger King',
#     'website': 'https://burgerking.com/store-locator/store/restaurant_13241',
#     'phone': '+1 469-334-0058'},
#    {'name': 'Uptown Thai Market',
#     'website': 'http://www.uptownthaidallas.com/',
#     'phone': '+1 469-334-0434'},
#    {'name': "Raising Cane's Chicken Fingers",
#     'website': 'http://raisingcanes.com/',
#     'phone': '+1 214-515-9105'},
#    {'name': 'La Popular Tamale House',
#     'website': 'http://www.lapopulartamalehouse.com/',
#     'phone': '+1 214-824-7617'},
#    {'name': 'Popeyes Louisiana Kitchen',
#     'website': 'https://www.popeyes.com/store-locator/store/restaurant_82691',
#     'phone': '+1 214-821-8870'},
#    {'name': 'Marysols Mexican Restaurant',
#     'website': '...',
#     'phone': '+1 214-823-8879'},
#    {'name': 'Dallasite Billiards',
#     'website': '...',
#     'phone': '+1 214-826-3670'},
#    {'name': 'Sakhuu Thai Restaurant (Dallas Location)',
#     'website': 'https://order.sakhuuthai.com/order/sakhuu-thai-restaurant-dallas-location',
#     'phone': '+1 214-828-9300'},
#    {'name': 'Bull Sandwich', 'website': '...', 'phone': '...'},
#    {'name': "Giuseppe's Italian Kitchen",
#     'website': 'https://giuseppes-italian-kitchen.business.site/',
#     'phone': '+1 469-766-0181'},
#    {'name': 'Khao Noodle Shop',
#     'website': 'http://khaodallas.com/',
#     'phone': '+1 972-803-3373'},
#    {'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/dallas/4801-ross-avenue.html',
#     'phone': '+1 469-778-2433'},
#    {'name': 'Pizza Patron',
#     'website': 'https://www.pizzapatron.com/',
#     'phone': '+1 214-841-9193'},
#    {'name': 'Top Round',
#     'website': 'https://eattopround.com/',
#     'phone': '+1 214-647-1075'},
#    {'name': 'Palapas Seafood Bar',
#     'website': 'http://originalpalapas.com/',
#     'phone': '+1 214-824-3000'}]},
#  '40': {'name': '4919 San Jacinto',
#   'address': '4919 San Jacinto St, Knox Henderson',
#   'nearby': [{'name': "Mai's Restaurant Authentic Vietnamese Cuisine",
#     'website': 'http://www.maisrestaurant.net/',
#     'phone': '+1 214-826-9887'},
#    {'name': 'Urbano Cafe',
#     'website': 'http://www.urbanodallas.com/',
#     'phone': '+1 214-823-8550'},
#    {'name': 'Uptown Thai Market',
#     'website': 'http://www.uptownthaidallas.com/',
#     'phone': '+1 469-334-0434'},
#    {'name': 'Popeyes Louisiana Kitchen',
#     'website': 'https://www.popeyes.com/store-locator/store/restaurant_82691',
#     'phone': '+1 214-821-8870'},
#    {'name': 'Waffle House',
#     'website': 'http://www.wafflehouse.com/',
#     'phone': '+1 214-824-2539'},
#    {'name': 'Burger King',
#     'website': 'https://burgerking.com/store-locator/store/restaurant_13241',
#     'phone': '+1 469-334-0058'},
#    {'name': 'La Popular Tamale House',
#     'website': 'http://www.lapopulartamalehouse.com/',
#     'phone': '+1 214-824-7617'},
#    {'name': "Raising Cane's Chicken Fingers",
#     'website': 'http://raisingcanes.com/',
#     'phone': '+1 214-515-9105'},
#    {'name': 'Marysols Mexican Restaurant',
#     'website': '...',
#     'phone': '+1 214-823-8879'},
#    {'name': 'Dallasite Billiards',
#     'website': '...',
#     'phone': '+1 214-826-3670'},
#    {'name': 'Sakhuu Thai Restaurant (Dallas Location)',
#     'website': 'https://order.sakhuuthai.com/order/sakhuu-thai-restaurant-dallas-location',
#     'phone': '+1 214-828-9300'},
#    {'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/dallas/4801-ross-avenue.html',
#     'phone': '+1 469-778-2433'},
#    {'name': 'The Hubcap Cafe',
#     'website': 'https://www.dallas24hourclub.org/the-hubcap-cafe',
#     'phone': '+1 214-823-3200'},
#    {'name': "Giuseppe's Italian Kitchen",
#     'website': 'https://giuseppes-italian-kitchen.business.site/',
#     'phone': '+1 469-766-0181'},
#    {'name': 'Khao Noodle Shop',
#     'website': 'http://khaodallas.com/',
#     'phone': '+1 972-803-3373'},
#    {'name': 'Top Round',
#     'website': 'https://eattopround.com/',
#     'phone': '+1 214-647-1075'},
#    {'name': 'Bull Sandwich', 'website': '...', 'phone': '...'}]},
#  '41': {'name': '5005 San Jacinto',
#   'address': '5005 San Jacinto St, Knox Henderson',
#   'nearby': [{'name': "Mai's Restaurant Authentic Vietnamese Cuisine",
#     'website': 'http://www.maisrestaurant.net/',
#     'phone': '+1 214-826-9887'},
#    {'name': 'Urbano Cafe',
#     'website': 'http://www.urbanodallas.com/',
#     'phone': '+1 214-823-8550'},
#    {'name': 'Waffle House',
#     'website': 'http://www.wafflehouse.com/',
#     'phone': '+1 214-824-2539'},
#    {'name': 'Uptown Thai Market',
#     'website': 'http://www.uptownthaidallas.com/',
#     'phone': '+1 469-334-0434'},
#    {'name': 'Burger King',
#     'website': 'https://burgerking.com/store-locator/store/restaurant_13241',
#     'phone': '+1 469-334-0058'},
#    {'name': "Raising Cane's Chicken Fingers",
#     'website': 'http://raisingcanes.com/',
#     'phone': '+1 214-515-9105'},
#    {'name': 'Popeyes Louisiana Kitchen',
#     'website': 'https://www.popeyes.com/store-locator/store/restaurant_82691',
#     'phone': '+1 214-821-8870'},
#    {'name': 'La Popular Tamale House',
#     'website': 'http://www.lapopulartamalehouse.com/',
#     'phone': '+1 214-824-7617'},
#    {'name': 'Marysols Mexican Restaurant',
#     'website': '...',
#     'phone': '+1 214-823-8879'},
#    {'name': 'Dallasite Billiards',
#     'website': '...',
#     'phone': '+1 214-826-3670'},
#    {'name': 'Sakhuu Thai Restaurant (Dallas Location)',
#     'website': 'https://order.sakhuuthai.com/order/sakhuu-thai-restaurant-dallas-location',
#     'phone': '+1 214-828-9300'},
#    {'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/dallas/4801-ross-avenue.html',
#     'phone': '+1 469-778-2433'},
#    {'name': 'Bull Sandwich', 'website': '...', 'phone': '...'},
#    {'name': "Giuseppe's Italian Kitchen",
#     'website': 'https://giuseppes-italian-kitchen.business.site/',
#     'phone': '+1 469-766-0181'},
#    {'name': 'Khao Noodle Shop',
#     'website': 'http://khaodallas.com/',
#     'phone': '+1 972-803-3373'},
#    {'name': 'Top Round',
#     'website': 'https://eattopround.com/',
#     'phone': '+1 214-647-1075'},
#    {'name': 'The Hubcap Cafe',
#     'website': 'https://www.dallas24hourclub.org/the-hubcap-cafe',
#     'phone': '+1 214-823-3200'}]},
#  '42': {'name': 'Creek Cove Villas',
#   'address': '130 Creek Cove Dr, ',
#   'nearby': []},
#  '43': {'name': 'Garden Terrace Duplex Homes',
#   'address': '11803-11905 Garden Terrace Dr, Dallas',
#   'nearby': [{'name': 'La paloma', 'website': '...', 'phone': '...'},
#    {'name': 'Jack in the Box',
#     'website': 'http://www.jackinthebox.com/locations/749',
#     'phone': '+1 214-340-3321'},
#    {'name': 'Abeba Grocery',
#     'website': 'https://www.abebagrocery.com/',
#     'phone': '+1 972-982-2687'},
#    {'name': 'Sinï Coffee Lounge',
#     'website': '...',
#     'phone': '+1 214-647-1598'}]},
#  '44': {'name': 'Ridge at Trinity Apartments',
#   'address': '7203 Great Trinity Forest Way, South Boulevard-Park Row',
#   'nearby': [{'name': 'Go Loco Street Tacos & Burritos',
#     'website': 'http://www.goloco.com/',
#     'phone': '+1 214-238-2935'}]},
#  '45': {'name': '4230 McKinney Ave',
#   'address': '4230 McKinney Ave, Uptown Dallas',
#   'nearby': [{'name': 'Salum Restaurant',
#     'website': 'http://www.salumrestaurant.com/',
#     'phone': '+1 214-252-9604'},
#    {'name': 'BuzzBrews Kitchen',
#     'website': 'http://www.buzzbrews.com/',
#     'phone': '+1 214-826-7100'},
#    {'name': "McDonald's",
#     'website': 'https://www.mcdonalds.com/us/en-us/location/TX/DALLAS/4151-N-CENTRAL-EXPY/22114.html?cid=RF:YXT:GMB::Clicks',
#     'phone': '+1 214-219-0562'},
#    {'name': 'Jack in the Box',
#     'website': 'https://locations.jackinthebox.com/us/tx/dallas/4210-n-central-expy',
#     'phone': '+1 214-823-3650'},
#    {'name': 'Snap Kitchen',
#     'website': 'https://www.snapkitchen.com/locations/fitzhugh/16?utm_source=google&utm_medium=organic&utm_campaign=localmaps',
#     'phone': '+1 214-613-4490'},
#    {'name': "Denny's",
#     'website': 'https://locations.dennys.com/TX/DALLAS/247712?utm_source=yext&utm_medium=local-listing&utm_campaign=yext-listing',
#     'phone': '+1 214-824-1269'},
#    {'name': 'The tradition', 'website': '...', 'phone': '...'},
#    {'name': "Beverley's Dallas",
#     'website': 'https://beverleysdallas.com/',
#     'phone': '+1 214-915-8840'},
#    {'name': 'Hungry Belly',
#     'website': 'http://hungrybellydallas.com/',
#     'phone': '+1 214-258-5859'},
#    {'name': 'Executive Snack Shop',
#     'website': '...',
#     'phone': '+1 214-827-2525'}]},
#  '46': {'name': 'The Principal Residences',
#   'address': '401 N Carroll Ave, Old East Dallas',
#   'nearby': [{'name': 'Aca Las Tortas',
#     'website': 'https://aca-las-tortas-mexican-restaurant.business.site/',
#     'phone': '+1 469-730-3141'},
#    {'name': "Domino's Pizza",
#     'website': 'https://www.dominos.com/en/?utm_source=google&utm_medium=loclist&utm_campaign=localmaps',
#     'phone': '+1 214-828-9090'},
#    {'name': "Church's Chicken",
#     'website': 'https://locations.churchs.com/tx/dallas/4210-gaston-avenue',
#     'phone': '+1 214-823-2856'},
#    {'name': 'taqueria los chapulines',
#     'website': '...',
#     'phone': '+1 214-429-6202'},
#    {'name': 'Egg Roll Hut',
#     'website': 'http://www.eggrollhut.com/',
#     'phone': '+1 214-823-4131'},
#    {'name': 'La Pasadita', 'website': '...', 'phone': '+1 214-824-1909'}]},
#  '47': {'name': 'Eleven600 Apartments',
#   'address': '11600 Audelia Rd, Dallas',
#   'nearby': [{'name': 'Aggies Restaurant',
#     'website': '...',
#     'phone': '+1 214-221-7276'},
#    {'name': "Big Mama's Chicken And Waffles",
#     'website': '...',
#     'phone': '+1 214-340-3035'},
#    {'name': 'Pizza Patron',
#     'website': 'https://www.pizzapatron.com/',
#     'phone': '+1 214-348-9191'},
#    {'name': 'Little Caesars Pizza',
#     'website': 'https://littlecaesars.com/en-us/store/10279',
#     'phone': '+1 214-503-6000'},
#    {'name': "Bo's Chicken & Seafood",
#     'website': '...',
#     'phone': '+1 972-685-5767'},
#    {'name': 'Cyc Fashion', 'website': '...', 'phone': '+1 214-564-8396'},
#    {'name': 'Jambo Safari', 'website': '...', 'phone': '+1 214-553-8111'},
#    {'name': 'Mardi Gras Daiquiri',
#     'website': '...',
#     'phone': '+1 972-913-4909'},
#    {'name': 'CAFE LAZIZ',
#     'website': 'http://cafelazizdallas.com/',
#     'phone': '+1 469-802-6017'},
#    {'name': 'Star Subs', 'website': '...', 'phone': '...'}]},
#  '48': {'name': 'The View at Lake Highlands',
#   'address': '9855 Shadow Way, Dallas',
#   'nearby': [{'name': 'Easy', 'website': '...', 'phone': '...'}]},
#  '49': {'name': 'M-Line Tower',
#   'address': '3200 McKinney Ave, Uptown Dallas',
#   'nearby': [{'name': "Del Frisco's Grille",
#     'website': 'https://delfriscosgrille.com/dallas?utm_source=yext&utm_medium=localsearch&utm_campaign=landingpage&utm_content=dallas',
#     'phone': '+1 972-807-6152'},
#    {'name': 'Bread Winners Café & Bakery',
#     'website': 'http://www.breadwinnerscafe.com/',
#     'phone': '+1 214-754-4940'},
#    {'name': 'Starbucks',
#     'website': 'http://www.starbucks.com/store/8841/',
#     'phone': '+1 214-965-9696'},
#    {'name': 'The Original Pancake House',
#     'website': 'http://ophdfw.com/',
#     'phone': '+1 214-528-7215'},
#    {'name': "Primo's MX Kitchen & Lounge",
#     'website': 'https://www.primosuptown.com/',
#     'phone': '+1 214-935-5111'},
#    {'name': 'i Fratelli Pizza Uptown',
#     'website': 'https://www.ifratellipizza.com/',
#     'phone': '+1 214-720-0070'},
#    {'name': 'Southpaw Grill',
#     'website': 'http://www.southpawsgrill.com/',
#     'phone': '+1 214-754-0100'},
#    {'name': 'Hook Line & Sinker',
#     'website': 'http://hookline-sinker.com/',
#     'phone': '+1 214-965-0707'},
#    {'name': 'Hopdoddy Burger Bar',
#     'website': 'https://www.hopdoddy.com/locations/',
#     'phone': '+1 214-871-2337'},
#    {'name': 'The Loon',
#     'website': 'https://www.theloonbar.com/?utm_source=local&utm_medium=organic&utm_campaign=gmb',
#     'phone': '+1 214-303-1151'},
#    {'name': "Jimmy John's",
#     'website': 'https://locations.jimmyjohns.com/tx/dallas/sandwiches-2273.html?utm_source=google%20my%20business&utm_medium=organic&utm_campaign=website%20link',
#     'phone': '+1 214-720-3800'},
#    {'name': 'Blue Sushi Sake Grill',
#     'website': 'http://bluesushisakegrill.com/locations/texas/dallas/uptown-dallas',
#     'phone': '+1 469-718-2292'},
#    {'name': 'San Martin Bakery and Restaurant',
#     'website': 'http://www.sanmartinbakery.com/',
#     'phone': '+1 469-802-6652'},
#    {'name': "Primo's MX Kitchen & Lounge",
#     'website': 'https://www.primosuptown.com/',
#     'phone': '+1 214-935-5111'},
#    {'name': "Harris' House of Heroes",
#     'website': 'http://harrishouseofheroestx.com/',
#     'phone': '+1 469-248-2256'},
#    {'name': 'Gaslight Dallas', 'website': '...', 'phone': '+1 214-446-9466'},
#    {'name': 'Urban Donut',
#     'website': 'https://www.urban-donut.com/',
#     'phone': '+1 469-687-5888'},
#    {'name': 'Velvet Taco',
#     'website': 'https://velvettaco.com/',
#     'phone': '+1 469-862-8226'},
#    {'name': 'CutiePies Pizza & Bar',
#     'website': 'https://www.cutiepiespizza.com/',
#     'phone': '+1 214-238-6348'},
#    {'name': 'Cobb Properties', 'website': '...', 'phone': '...'}]},
#  '50': {'name': 'The Christopher',
#   'address': '2323 N Akard St, Victory Park',
#   'nearby': [{'name': 'El Fenix',
#     'website': 'https://www.elfenix.com/',
#     'phone': '+1 214-747-1121'},
#    {'name': "Del Frisco's Double Eagle Steakhouse",
#     'website': 'https://delfriscos.com/steakhouse/dallas?utm_source=yext&utm_medium=localsearch&utm_campaign=landingpage&utm_content=dallas',
#     'phone': '+1 972-490-9000'},
#    {'name': "Perry's Steakhouse & Grille",
#     'website': 'https://perryssteakhouse.com/locations/tx/dallas/uptown/',
#     'phone': '+1 214-855-5151'},
#    {'name': 'Meso Maya Comida y Copas',
#     'website': 'https://www.mesomaya.com/locations/',
#     'phone': '+1 214-484-6555'},
#    {'name': 'Mercat Bistro',
#     'website': 'http://www.mercatbistro.com/',
#     'phone': '+1 214-953-0917'},
#    {'name': "Murphy's Deli",
#     'website': 'http://murphysdeli.com/',
#     'phone': '+1 214-953-6260'},
#    {'name': 'Taqueria La Ventana',
#     'website': 'http://taquerialaventana.com/',
#     'phone': '+1 214-484-6803'},
#    {'name': 'Roti Modern Mediterranean',
#     'website': 'https://roti.com/location/dallas-uptown/',
#     'phone': '+1 972-364-7804'},
#    {'name': 'Freshii',
#     'website': 'http://www.freshii.com/us',
#     'phone': '+1 469-802-9299'},
#    {'name': 'SunFresh Harvest',
#     'website': 'http://www.sunfreshharvest.com/contact.html',
#     'phone': '+1 972-900-7939'},
#    {'name': 'Shooters',
#     'website': 'http://shootersdallas.com/',
#     'phone': '+1 972-925-9013'},
#    {'name': 'Dr Pepper Fan Zone', 'website': '...', 'phone': '...'},
#    {'name': 'North Italia',
#     'website': 'https://www.northitalia.com/locations/dallas-tx-uptown/',
#     'phone': '+1 972-619-3770'},
#    {'name': 'TacoLingo Tex-Mex',
#     'website': 'https://www.tacolingo.com/',
#     'phone': '+1 214-613-4041'},
#    {'name': 'The Henry',
#     'website': 'https://www.thehenryrestaurant.com/locations/the-henry-dallas/',
#     'phone': '+1 972-677-9560'},
#    {'name': 'CAVA', 'website': 'http://cava.com/', 'phone': '+1 214-281-8367'},
#    {'name': 'Te Deseo',
#     'website': 'http://www.tedeseodallas.com/',
#     'phone': '+1 214-646-1314'},
#    {'name': 'Happiest Hour',
#     'website': 'https://www.happiesthourdallas.com/',
#     'phone': '+1 972-528-0067'},
#    {'name': 'Wolfgang Puck Catering',
#     'website': 'https://wolfgangpuck.com/catering/perot-museum-nature-science/',
#     'phone': '+1 214-741-7825'},
#    {'name': "Doc B's Restaurant + Bar (Uptown Dallas)",
#     'website': 'https://docbsrestaurant.com/locations/dallas',
#     'phone': '+1 469-998-2330'}]},
#  '51': {'name': 'The View at Kessler Park',
#   'address': '2511 Wedglea Dr, North Oak Cliff',
#   'nearby': [{'name': 'Sonic Drive-In',
#     'website': 'https://locations.sonicdrivein.com/tx/dallas/2516-fort-worth-avenue.html',
#     'phone': '+1 214-946-2080'},
#    {'name': 'El Tiz Tizoncito Kessler Park',
#     'website': 'http://www.tiztaco.com/',
#     'phone': '+1 214-948-4858'}]},
#  '52': {'name': 'The Brazos',
#   'address': '4341 Horizon North Pky, Far North Dallas',
#   'nearby': []},
#  '53': {'name': 'Galleries at Park Lane',
#   'address': '8110 Park Ln, Vickery',
#   'nearby': [{'name': 'Bowl & Barrel',
#     'website': 'http://www.bowlandbarrel.com/',
#     'phone': '+1 214-363-2695'},
#    {'name': 'Taco Cabana',
#     'website': 'http://www.tacocabana.com/',
#     'phone': '+1 214-739-1218'},
#    {'name': 'Pizza Hut',
#     'website': 'https://locations.pizzahut.com/tx/dallas/8224-park-lane?utm_medium=organic&utm_source=local&utm_campaign=googlelistings&utm_content=website&utm_term=289058',
#     'phone': '+1 214-363-7733'},
#    {'name': "Grimaldi's Pizzeria",
#     'website': 'https://www.grimaldispizzeria.com/locations/park-lane/',
#     'phone': '+1 214-987-1173'},
#    {'name': 'Which Wich Park Lane',
#     'website': 'http://www.whichwich.com/',
#     'phone': '+1 214-368-9424'},
#    {'name': "Norma's Cafe",
#     'website': 'http://www.normascafe.com/',
#     'phone': '+1 214-361-8646'},
#    {'name': 'Slim Chickens',
#     'website': 'https://slimchickens.com/location/dallas-tx-9100-n-central-expressway-75231/',
#     'phone': '+1 469-466-9016'},
#    {'name': 'Zoës Kitchen',
#     'website': 'https://zoeskitchen.com/locations/store/tx/park-lane',
#     'phone': '+1 469-232-9203'},
#    {'name': "Jason's Deli",
# ...
#     'phone': '+1 203-747-8483'},
#    {'name': 'Chipotle Mexican Grill',
#     'website': 'https://locations.chipotle.com/ct/new-haven/910-chapel-st?utm_source=google&utm_medium=yext&utm_campaign=yext_listings',
#     'phone': '+1 203-785-0799'},
#    {'name': 'Jeera Thai', 'website': '...', 'phone': '+1 203-562-5856'},
#    {'name': 'ROÌA Restaurant and Cafe',
#     'website': 'http://roiarestaurant.com/',
#     'phone': '+1 203-200-7045'},
#    {'name': 'Atticus Bookstore Cafe',
#     'website': 'http://atticusbookstorecafe.com/',
#     'phone': '+1 203-776-4040'},
#    {'name': 'Cask Republic',
#     'website': 'http://caskrepublic.com/',
#     'phone': '+1 475-238-8335'},
#    {'name': 'Subway',
#     'website': 'https://order.subway.com/en-us/restaurant/6147/menu/?utm_source=yxt-goog&utm_medium=local&utm_term=acq&utm_content=6147&utm_campaign=evergreen-2020&y_source=1_MTQ4OTcxNTQtNzE1LWxvY2F0aW9uLmdvb2dsZV93ZWJzaXRlX292ZXJyaWRl',
#     'phone': '+1 203-497-9324'},
#    {'name': 'Temple Grill',
#     'website': 'https://www.templegrillmenu.com/',
#     'phone': '+1 203-773-1111'},
#    {'name': 'Miso',
#     'website': 'http://www.misorestaurant.com/',
#     'phone': '+1 203-848-6472'},
#    {'name': 'Soul de Cuba Cafe',
#     'website': 'http://www.souldecuba.com/',
#     'phone': '+1 203-498-2822'},
#    {'name': 'Skappo Italian Wine Bar',
#     'website': 'http://www.skappo.com/',
#     'phone': '+1 203-773-1394'},
#    {'name': 'Lalibela Ethiopian Restaurant',
#     'website': 'http://lalibelarestaurantct.com/',
#     'phone': '+1 203-789-1232'},
#    {'name': 'Panera Bread',
#     'website': 'https://locations.panerabread.com/ct/new-haven/1060-chapel-street.html?utm_medium=display-ad&utm_source=paid-digital&utm_campaign=yext&utm_content=local-search',
#     'phone': '+1 203-624-0873'},
#    {'name': 'Basta Trattoria',
#     'website': 'http://www.bastatrattoria.com/',
#     'phone': '+1 203-772-1715'},
#    {'name': '116 Crown',
#     'website': 'http://www.116crown.com/',
#     'phone': '+1 203-777-3116'},
#    {'name': 'Pho Ketkeo', 'website': '...', 'phone': '+1 203-745-5480'},
#    {'name': 'Mecha Noodle Bar',
#     'website': 'https://mechanoodlebar.com/',
#     'phone': '+1 203-691-9671'},
#    {'name': 'Olives and Oil New Haven',
#     'website': 'http://www.olivesandoil.com/',
#     'phone': '+1 203-891-5870'},
#    {'name': "Jack's Bar And Steakhouse",
#     'website': 'http://www.jacksnewhaven.com/',
#     'phone': '+1 203-891-5777'},
#    {'name': 'Pitaziki Mediterranean Grill',
#     'website': 'http://pitaziki.com/',
#     'phone': '+1 203-773-5000'},
#    {'name': 'Cajun Boiled Seafood',
#     'website': 'http://cajunboiledseafoodct.com/',
#     'phone': '+1 203-691-5682'},
#    {'name': 'Kitchen ZINC',
#     'website': 'http://kitchenzinc.com/',
#     'phone': '+1 203-772-3002'},
#    {'name': 'Meat & Co.',
#     'website': 'http://www.meatandcompany.com/',
#     'phone': '+1 203-776-6328'},
#    {'name': "New Haven's Taste of China",
#     'website': 'http://www.tasteofchinaus.com/newhaven/',
#     'phone': '+1 203-745-5872'},
#    {'name': 'Elm City Social',
#     'website': 'http://www.elmcitysocial.com/',
#     'phone': '+1 475-441-7436'},
#    {'name': 'The Halal Guys',
#     'website': 'http://www.thehalalguys.com/',
#     'phone': '+1 203-691-5166'},
#    {'name': 'Five Guys',
#     'website': 'https://order.fiveguys.com/menu/five-guys-619/',
#     'phone': '+1 203-859-5565'},
#    {'name': 'B Natural Cafe', 'website': '...', 'phone': '+1 203-773-1343'},
#    {'name': 'Harvest Wine Bar & Restaurant',
#     'website': 'http://harvestwinebar.com/',
#     'phone': '+1 203-777-2500'},
#    {'name': 'Hunan House', 'website': '...', 'phone': '+1 203-776-6663'}]},
#  '477': {'name': 'The Cottages at Ridge Pointe',
#   'address': '940 Creek Ridge Ln, Athens',
#   'nearby': []},
#  '478': {'name': 'Lullwater at Jennings Mill',
#   'address': '225 Jennings Mill Pky, Athens',
#   'nearby': []},
#  '479': {'name': 'Grand Preserve',
#   'address': '355 The Preserve Dr, Athens',
#   'nearby': []},
#  '480': {'name': 'The Oaks',
#   'address': '175 Woodlake Pl, Eastside Athens',
#   'nearby': []},
#  '481': {'name': '755 Broad, a Georgia Tradition',
#   'address': '755 E Broad St, Downtown Athens',
#   'nearby': [{'name': "Weaver D's Delicious Fine Foods",
#     'website': 'http://weaverds.com/',
#     'phone': '+1 706-353-7797'},
#    {'name': 'Mellow Mushroom Athens',
#     'website': 'https://mellowmushroom.com/location/ga-athens-320-e-clayton-st-30601/',
#     'phone': '+1 706-613-0892'},
#    {'name': "DePalma's Italian Cafe",
#     'website': 'http://www.depalmasitaliancafe.com/',
#     'phone': '+1 706-354-6966'},
#    {'name': 'Porterhouse Grill',
#     'website': 'http://www.porterhouseathens.com/',
#     'phone': '+1 706-369-0990'},
#    {'name': 'East West Bistro',
#     'website': 'http://www.eastwestbistro.com/',
#     'phone': '+1 762-233-9660'},
#    {'name': 'Athens Bagel Company',
#     'website': 'http://www.athensbagel.com/',
#     'phone': '+1 706-543-5001'},
#    {'name': 'Athens Wok',
#     'website': 'http://athenswokga.com/',
#     'phone': '+1 706-850-2695'},
#    {'name': 'Zombie Coffee and Donuts',
#     'website': 'http://eatzombiedonuts.com/',
#     'phone': '+1 706-850-2526'},
#    {'name': 'Taqueria Tsunami',
#     'website': 'http://taqueriatsunami.com/',
#     'phone': '+1 706-621-7999'},
#    {'name': 'Pita Pit',
#     'website': 'https://locations.pitapitusa.com/ll/US/GA/Athens/123-N-Jackson-St',
#     'phone': '+1 706-552-0051'},
#    {'name': 'Blind Pig Tavern',
#     'website': 'http://www.blindpigtavern.com/',
#     'phone': '+1 706-548-3442'},
#    {'name': 'Utage Sushi Bar',
#     'website': 'https://utagesushibar.restaurant/',
#     'phone': '+1 706-227-9339'},
#    {'name': 'Eddies Calzones',
#     'website': 'http://www.eddiescalzones.com/',
#     'phone': '+1 706-549-9676'},
#    {'name': 'Knuckies Pizza & Hoagies of Athens',
#     'website': 'http://knuckiespizzaandhoagies.com/',
#     'phone': '+1 706-395-4458'},
#    {'name': 'I Heart Mac and Cheese',
#     'website': '...',
#     'phone': '+1 706-945-3585'},
#    {'name': 'Frutta Bowls',
#     'website': 'https://www.fruttabowls.com/location/frutta-bowls-athens-georgia/',
#     'phone': '+1 706-514-0060'},
#    {'name': 'Cravings', 'website': '...', 'phone': '+1 706-850-0049'},
#    {'name': 'Ahi Hibachi and Poke',
#     'website': 'https://www.ahihibachi.com/',
#     'phone': '+1 706-543-8898'},
#    {'name': 'El Azteca Mexican Restaurant - Athens',
#     'website': 'https://www.elaztecaatlanta.com/',
#     'phone': '+1 706-850-6950'},
#    {'name': 'Jinya Ramen Bar',
#     'website': 'http://jinya-ramenbar.com/',
#     'phone': '+1 706-478-0880'}]},
#  '482': {'name': 'High Ridge Apartments',
#   'address': '700 Mitchell Bridge Rd, Westside Athens',
#   'nearby': []},
#  '483': {'name': 'Georgia Green',
#   'address': '700 Fourth St, Northeast Athens',
#   'nearby': []},
#  '484': {'name': 'Legacy of Athens',
#   'address': '100 Ashley Cir, Eastside Athens',
#   'nearby': [{'name': 'Taqueria La Parrilla',
#     'website': 'http://www.lapa.us/',
#     'phone': '+1 706-548-5040'}]},
#  '485': {'name': 'Westpark Club',
#   'address': '150 West Park Dr, Jennings Mill',
#   'nearby': []},
#  '486': {'name': 'The Columns at Timothy Woods',
#   'address': '2035 Timothy Rd, Kingswood',
#   'nearby': [{'name': 'Outback Steakhouse',
#     'website': 'https://www.outback.com/',
#     'phone': '+1 706-613-6015'},
#    {'name': 'Locos Grill and Pub',
#     'website': 'http://www.locosgrill.com/',
#     'phone': '+1 706-549-7700'},
#    {'name': 'China Star Superbuffet',
#     'website': 'http://www.chinastarathens.com/',
#     'phone': '+1 706-316-3382'},
#    {'name': 'Sakura Steak House',
#     'website': 'https://sakurahibachiathens.com/',
#     'phone': '+1 706-227-0001'},
#    {'name': 'Dos Palmas Mexican Grill',
#     'website': 'http://athens-dospalmas.com/',
#     'phone': '+1 706-353-7771'},
#    {'name': 'DePalmas Italian Cafe - West Side',
#     'website': 'http://depalmasitaliancafe.com/',
#     'phone': '+1 706-552-1237'},
#    {'name': 'Agua Linda Mexican Restaurant',
#     'website': '...',
#     'phone': '+1 706-543-0154'},
#    {'name': "Captain D's",
#     'website': 'https://locations.captainds.com/ll/US/GA/Athens/3597-Atlanta-Hwy',
#     'phone': '+1 706-548-8395'}]},
#  '487': {'name': 'Cambridge Apartments',
#   'address': '360 Piccadilly Sq, Eastside Athens',
#   'nearby': [{'name': 'Barberitos Southwestern Grille & Cantina',
#     'website': 'https://www.barberitos.com/',
#     'phone': '+1 706-549-9954'},
#    {'name': "Papa John's Pizza",
#     'website': 'https://locations.papajohns.com/united-states/ga/30605/athens/1860-barnett-shoals-rd?utm_source=gmb&utm_medium=organic&y_source=1_MTA2OTI1NDYtNzE1LWxvY2F0aW9uLmdvb2dsZV93ZWJzaXRlX292ZXJyaWRl',
#     'phone': '+1 706-354-4444'},
#    {'name': 'Inoko Hibachi Express',
#     'website': 'http://inokoathens.com/',
#     'phone': '+1 706-546-5662'},
#    {'name': "Beef 'O' Brady's",
#     'website': 'https://www.beefobradys.com/athens',
#     'phone': '+1 706-850-1916'},
#    {'name': 'Waffle House',
#     'website': 'http://www.wafflehouse.com/',
#     'phone': '+1 706-208-1252'},
#    {'name': 'Inoko Hibachi Express Eastside',
#     'website': 'http://inokoathens.com/',
#     'phone': '+1 706-546-5662'},
#    {'name': 'Beef o Bradys', 'website': '...', 'phone': '...'}]},
#  '488': {'name': 'Arch + Vine Athens',
#   'address': '105 Oak Hill Dr, Northeast Athens',
#   'nearby': []},
#  '489': {'name': 'ACCENT ATHENS',
#   'address': '100 Still Creek Ln, Athens',
#   'nearby': []},
#  '490': {'name': 'Red Oak Village',
#   'address': '232 Epps Bridge Rd, Epps Bridge',
#   'nearby': [{'name': 'Peking Restaurant',
#     'website': 'http://www.westpekingathens.com/',
#     'phone': '+1 706-549-9333'},
#    {'name': "Kelly's Authentic Jamaican Food",
#     'website': '...',
#     'phone': '+1 706-369-5400'}]},
#  '491': {'name': 'The Redland Apartments',
#   'address': '505 Riverbend Pky, Riverbend',
#   'nearby': []},
#  '492': {'name': 'Archer Apartments',
#   'address': '210 Spring Ct, Northeast Athens',
#   'nearby': []},
#  '493': {'name': 'The Standard at Athens',
#   'address': '600 N Thomas St, Downtown Athens',
#   'nearby': [{'name': 'Graduate Athens',
#     'website': 'https://www.graduatehotels.com/athens/',
#     'phone': '+1 706-549-7020'},
#    {'name': 'Athens Bagel Company',
#     'website': 'http://www.athensbagel.com/',
#     'phone': '+1 706-543-5001'},
#    {'name': 'Blind Pig Tavern',
#     'website': 'http://www.blindpigtavern.com/',
#     'phone': '+1 706-548-3442'},
#    {'name': 'Athens Wok',
#     'website': 'http://athenswokga.com/',
#     'phone': '+1 706-850-2695'},
#    {'name': "Lindsey's Culinary Market",
#     'website': 'http://www.lindseysculinarymarket.com/',
#     'phone': '+1 706-353-0558'},
#    {'name': 'The Foundry Bar & Mill',
#     'website': 'https://www.graduatehotels.com/athens/restaurant/the-foundry/',
#     'phone': '+1 706-549-7020'},
#    {'name': 'South Kitchen + Bar',
#     'website': 'https://www.southkitchenbar.com/',
#     'phone': '+1 706-395-6125'},
#    {'name': 'Ahi Hibachi and Poke',
#     'website': 'https://www.ahihibachi.com/',
#     'phone': '+1 706-543-8898'}]},
#  '494': {'name': '100 Prince',
#   'address': '100 Prince Ave, Athens',
#   'nearby': [{'name': 'The Grit',
#     'website': 'http://www.thegrit.com/',
#     'phone': '+1 706-543-6592'},
#    {'name': 'Last Resort Grill',
#     'website': 'http://lastresortgrill.com/',
#     'phone': '+1 706-549-0810'},
#    {'name': 'Big City Bread Cafe',
#     'website': 'http://www.bigcitybreadcafe.com/',
#     'phone': '+1 706-353-0029'},
#    {'name': 'The National',
#     'website': 'http://www.thenationalrestaurant.com/',
#     'phone': '+1 706-549-3450'},
#    {'name': 'Clocked',
#     'website': 'http://www.clockeddiner.com/',
#     'phone': '+1 706-548-9175'},
#    {'name': 'Taqueria Del Sol',
#     'website': 'http://www.taqueriadelsol.com/',
#     'phone': '+1 706-353-3890'},
#    {'name': "Hendershot's",
#     'website': 'http://www.hendershotsathens.com/',
#     'phone': '+1 706-353-3050'},
#    {'name': "Captain D's",
#     'website': 'https://locations.captainds.com/ll/US/GA/Athens/425-Prince-Ave',
#     'phone': '+1 706-548-8380'},
#    {'name': 'Viva! Argentine Cuisine',
#     'website': 'https://www.vivaargentine.com/',
#     'phone': '+1 706-850-8284'},
#    {'name': 'Iron Factory',
#     'website': 'http://www.ironfactoryinc.com/',
#     'phone': '+1 706-395-6877'},
#    {'name': 'The Bistro – Eat. Drink. Connect.®',
#     'website': 'http://www.marriott.com/hotels/hotel-information/restaurant/ahncy-courtyard-athens-downtown/?scid=bb1a189a-fec3-4d19-a255-54ba596febe2',
#     'phone': '+1 706-369-7000'},
#    {'name': "Ted's Most Best",
#     'website': 'http://www.tedsmostbest.com/',
#     'phone': '+1 706-543-1523'},
#    {'name': 'Dawg Gone Good BBQ',
#     'website': 'https://www.dawggonegoodbbq.com/#/',
#     'phone': '+1 706-613-9799'},
#    {'name': 'The World Famous',
#     'website': 'https://m.facebook.com/theworldfamousathens/',
#     'phone': '+1 706-543-4002'},
#    {'name': "Wendy's",
#     'website': 'https://locations.wendys.com/united-states/ga/athens/415-prince-ave?utm_source=Yext&utm_medium=Google_My_Business&utm_campaign=Local_Search&utm_content=EN_US',
#     'phone': '+1 706-850-3143'},
#    {'name': 'Wing Zone',
#     'website': 'https://www.wingzone.com/athens/?utm_source=GMB&utm_medium=organic&utm_campaign=athens',
#     'phone': '+1 706-214-2536'},
#    {'name': 'Shokitini',
#     'website': 'http://shokitini.com/',
#     'phone': '+1 706-353-7933'},
#    {'name': 'FIVE Athens',
#     'website': 'https://www.five-bar.com/location/athens-georgia/',
#     'phone': '+1 706-543-5515'},
#    {'name': "Taziki's Mediterranean Cafe - Athens",
#     'website': 'http://tazikiscafe.com/location/athens/',
#     'phone': '+1 706-247-7619'},
#    {'name': 'Seabear Oyster Bar',
#     'website': 'http://seabearoysterbar.com/',
#     'phone': '+1 706-850-4367'}]},
#  '495': {'name': 'The Preserve',
#   'address': '150 The Preserve Dr, Westside Athens',
#   'nearby': [{'name': "Domino's Pizza",
#     'website': 'https://www.dominos.com/en/?utm_source=google&utm_medium=loclist&utm_campaign=localmaps',
#     'phone': '+1 706-354-1179'},
#    {'name': 'International Grill and Bar',
#     'website': 'https://international-grill-and-bar.business.site/?utm_source=gmb&utm_medium=referral',
#     'phone': '+1 706-850-1509'}]},
#  '496': {'name': 'Athens Ridge',
#   'address': '1000 Redwood Ln, Athens',
#   'nearby': []},
#  '497': {'name': 'The Fairways at Jennings Mill',
#   'address': '355 Jennings Mill Pky, Jennings Mill',
#   'nearby': [{'name': 'Athens Skate Inn',
#     'website': 'http://athensskateinn.com/',
#     'phone': '+1 706-353-3113'}]},
#  '498': {'name': '1287 Shoals Apartments',
#   'address': '1287 Cedar Shoals Dr, Cedar Creek',
#   'nearby': [{'name': "Cali N Tito's",
#     'website': 'https://m.facebook.com/pages/category/Cuban-Restaurant/Cali-n-Titos-East-at-La-Puerta-del-Sol-855973477765690/',
#     'phone': '+1 706-355-7087'}]},
#  '499': {'name': 'Arbor Ridge',
#   'address': '150 Chateau Ter, Epps Bridge',
#   'nearby': [{'name': 'Peking Restaurant',
#     'website': 'http://www.westpekingathens.com/',
#     'phone': '+1 706-549-9333'},
#    {'name': "Kelly's Authentic Jamaican Food",
#     'website': '...',
#     'phone': '+1 706-369-5400'}]},
#  '500': {'name': 'Legacy Mill',
#   'address': '125 Jennings Mill Pky, Jennings Mill',
#   'nearby': []},
#  '501': {'name': 'University Gardens',
#   'address': '189 Baxter Dr, Baxter',
#   'nearby': [{'name': "Mama Jewel's Kitchen",
#     'website': 'http://www.mamajewelskitchen.com/',
#     'phone': '+1 706-850-9797'},
#    {'name': 'The Table Bistro',
#     'website': 'http://thetablebistro.square.site/',
#     'phone': '+1 706-395-6599'},
#    {'name': 'IHOP',
#     'website': 'https://www.ihop.com/en/restaurants-athens-ga/1180-baxter-st-434?utm_source=Google&utm_medium=Maps&utm_campaign=Google+Places',
#     'phone': '+1 706-354-1356'},
#    {'name': 'Classic City Eats',
#     'website': 'http://www.classiccityeats.com/',
#     'phone': '+1 706-850-3092'},
#    {'name': 'Mama jewel', 'website': '...', 'phone': '+1 706-850-9797'},
#    {'name': 'D92 Korean BBQ',
#     'website': 'https://www.d92kbbq.com/',
#     'phone': '+1 706-850-7990'}]}}

# %%
# Out:
#   File "<ipython-input-219-696bd4233b98>", line 1
#     repr(final) -> string
#                 ^
# SyntaxError: invalid syntax

# %%
temp = json.dumps(final, indent = 2)

# %%
text_file = open("output.txt", "wt")
n = text_file.write(temp)
text_file.close()
